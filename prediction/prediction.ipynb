# %% [markdown]
# # Prediction
#
# TODO: Make R log scaled.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
# Add the project root to the Python path
project_root = Path.cwd().parent  # Adjust this path to point to your project root
sys.path.append(str(project_root))

import numpy as np
import prediction
from load_data import loadStockData
from kelly_solver.plot import *

df = loadStockData('../stock.csv')

R_RANGE = 11
R = np.linspace(-0.05, 0.05, R_RANGE)
P = prediction.prediction(df, ['SPY'], '2016/12/30', R)

print(R)
print(P)
print(f'e: {R.dot(P)}')

drawProbability1D(R, P)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 193.367584 193.041077 0.0016913861291811604
# 190.928375 193.367584 -0.01261436353261778
# 186.347717 190.928375 -0.02399149943008733
# 184.302277 186.347717 -0.010976469328035745
# 184.484726 184.302277 0.000989944361891911
# 185.973206 184.484726 0.00806831021880917
# 181.33493 185.973206 -0.024940560523541173
# 184.311844 181.33493 0.016416660595948027
# 180.355408 184.311844 -0.021465988913875748
# 180.595474 180.355408 0.0013310718134938574
# 178.281158 180.595474 -0.012814916945260716
# 179.279861 178.281158 0.005601842680425074
# 182.957825 179.279861 0.020515210015697203
# 180.192139 182.957825 -0.015116522072778337
# 182.650513 180.192139 0.013643070189649017
# 180.662704 182.650513 -0.010883128480454904
# 181.60379 180.662704 0.005209077353342463
# 186.030823 181.60379 0.024377426264066374
# 185.963593 186.030823 -0.00036139172485408514
# 182.612122 185.963593 -0.018022188891564404
# ...

# %%
# %load_ext autoreload
# %autoreload 2

from kelly_solver.multivariate_kelly import *
from kelly_solver.newtons_method import *

X = newtonsMethod(R, P, verbose=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Iteration 0: Investment fraction is: 0.00%, Log Return is: 0.00000
# Iteration 1: Investment fraction is: 100.00%, Log Return is: 0.00044
# Converged in 1 iterations.
